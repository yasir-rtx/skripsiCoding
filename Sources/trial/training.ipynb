# %%
from keras.models import load_model
from PIL import Image
from numpy import savez_compressed
from numpy import expand_dims
from numpy import asarray
from numpy import load
from os import listdir, mkdir
from os.path import isdir, exists
import cv2
import time
import pickle

# %%
MyFaceNet = load_model("../../Models/FaceNet/facenet_keras.h5")
HaarCascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))
savePath = "..\\..\\..\\Dataset\\Dataset\\"
if not exists(savePath):
    mkdir(savePath)

label = "18101152630069"
label = label + "\\"
name = "yasir"
    
labelPath = savePath + label
print(labelPath)
if not exists(labelPath):
    mkdir(labelPath)
else:
    print("label sudah ada")


signature_path = "../../Data/"

if len(listdir(signature_path)) > 0:
    mySignature = open("../../Data/signature.pkl", "rb")
    faceDatabase = pickle.load(mySignature)
    mySignature.close()
else:
    faceDatabase = {}
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ..\..\..\Dataset\Dataset\18101152630069\
# label sudah ada

# %%
faceDatabase
# Out:
# {}

# %%
# cap = cv2.VideoCapture(1)
# sum = 0

# # messagebox.showinfo("Detail Pose Pertama", "Deskripsi Pose\nTekan enter untuk memulai")
# print("Deskripsi Pose\nTekan enter untuk memulai")
# while 1:
#     # time.sleep(1)
#     _, liveView = cap.read()
#     face = HaarCascade.detectMultiScale(liveView, 1.3, 5)
#     if len(face) > 0:
#         x1, y1, w, h = face[0]
#     else :
#         x1, y1, w, h = 1,1,10,10
#     x1, y1 = abs(x1), abs(y1)
#     x2, y2 = x1+w, y1+h
#     cv2.rectangle(liveView, (x1,y1), (x2,y2), (0,255,0), 2)
    
#     key = cv2.waitKey(5) & 0xFF
#     if (sum == 0):
#         desc = "front"
#     elif (sum ==1):
#         desc = "side"
#     else:
#         desc = "glass"
#     if key == 13:
#         for i in range(10):
#             time.sleep(0.2)
#             _, imgVideo = cap.read()
            
#             FaceDetect = HaarCascade.detectMultiScale(imgVideo, 1.3, 5)
#             if len(FaceDetect) > 0:
#                 x1, y1, w, h = FaceDetect[0]
#             else :
#                 x1, y1, w, h = 1,1,10,10
                
#             x1, y1 = abs(x1), abs(y1)
#             x2, y2 = x1+w, y1+h
            
#             img = cv2.cvtColor(imgVideo, cv2.COLOR_RGB2BGR)
#             img = Image.fromarray(img)
#             img_array = asarray(img)
            
#             face = img_array[y1:y2, x1:x2]
#             face = Image.fromarray(face)
#             face = face.convert('RGB')
#             face = face.resize((160,160))
#             # face = asarray(face)
            
            
#             fileName = labelPath + name + "_" + desc + "_" + str(i) + ".jpg"
#             # cv2.imwrite(fileName, img_array)
#             face.save(fileName)
#             print(f"Menyimpan File : \"{fileName}\"")
#         sum+=1
        
#     cv2.imshow('res', liveView)
#     if sum == 3:
#         break
#     if key == 27:
#         break

    
# cv2.destroyAllWindows()
# cap.release()

# %%
cap = cv2.VideoCapture(1)
for i in range(3):
    desc = "front" if i==0 else "side" if i==1 else "glass"
    print(f"Proses rekam wajah dengan pose : {desc}")
    sum = 0
    while 1:
        key = cv2.waitKey(5) & 0xFF
        _, imgVideo = cap.read()
        FaceDetect = HaarCascade.detectMultiScale(imgVideo, 1.3, 5)
        if len(FaceDetect) > 0:
            x1, y1, w, h = FaceDetect[0]
        else :
            x1, y1, w, h = 1,1,10,10
        x1, y1 = abs(x1), abs(y1)
        x2, y2 = x1+w, y1+h
        img = cv2.cvtColor(imgVideo, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)
        img_array = asarray(img)
        face = img_array[y1:y2, x1:x2]
        face = Image.fromarray(face)
        face_save = face.resize((160,160))
        face = asarray(face_save)
        if key == 13:
            fileName = labelPath + name + "_" + desc + "_" + str(sum) + ".jpg"
            print(f"saving : {fileName}")
            face_save.save(fileName)
            sum+=1
        cv2.rectangle(imgVideo, (x1,y1), (x2,y2), (0,255,0), 2)
        cv2.imshow('Rekam Wajah', imgVideo)
        if sum == 10:
            break
        if key == 27:
            break
    cv2.destroyAllWindows()
cap.release()

for files in listdir(labelPath):
    file = labelPath + files
    face_raw = cv2.imread(file)
    face = cv2.cvtColor(face_raw, cv2.COLOR_BGR2RGB)
    face = Image.fromarray(face)
    face = face.resize((160,160))
    face = asarray(face)
    face = face.astype('float32')
    mean, std = face.mean(), face.std()
    face = (face - mean) / std

    face = expand_dims(face, axis=0)
    print(f"Training file : {files}")
    signature = MyFaceNet.predict(face)
    faceDatabase[name] = signature
    
mySignature = open("../../Data/signature.pkl", "wb")
pickle.dump(faceDatabase, mySignature)
mySignature.close()
# Out:
# Proses rekam wajah dengan pose : front
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_0.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_1.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_2.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_3.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_4.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_5.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_6.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_7.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_8.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_front_9.jpg
# Proses rekam wajah dengan pose : side
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_0.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_1.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_2.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_3.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_4.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_5.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_6.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_7.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_8.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_side_9.jpg
# Proses rekam wajah dengan pose : glass
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_0.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_1.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_2.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_3.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_4.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_5.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_6.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_7.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_8.jpg
# saving : ..\..\..\Dataset\Dataset\18101152630069\yasir_glass_9.jpg
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
